# %% [markdown]
# # Import libraries

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
from glob import glob

import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

import h5py

# load helper functions from nitorch
sys.path.insert(0,"../helper")
from dataloader_utils import show_h5_contents

# %% [markdown]
# ### UKBIOBANK
# X = full brain voxels

# %%
show_h5_contents("/ritter/share/data/UKBB_2020/h5files/*.h5", ignore='holdout')
# Out:
# ______________________________________________________________________________________
# filename: idps-l-bingeauditl1u3-c-sex-age-n13465.h5
#  h5.columns = ['X', 'age', 'bingeaudit', 'i', 'sex']
#  h5.attrs = ['X_col_names', 'confs', 'labels']
# n = 13465 	 label = bingeaudit 	 X.shape = (13465, 2521)  	 confs = ['sex', 'age']
# label and conf with distributions:
# subject: 1057098 	 (min=0.00, mean=8429.12, max=1456220.00)
# ______________________________________________________________________________________
# filename: idps-l-highalcl0u2-c-sex-age-n13465.h5
#  h5.columns = ['X', 'age', 'highalc', 'i', 'sex']
#  h5.attrs = ['X_col_names', 'confs', 'labels']
# n = 13465 	 label = highalc 	 X.shape = (13465, 2521)  	 confs = ['sex', 'age']
# label and conf with distributions:
# subject: 1324222 	 (min=0.00, mean=7916.66, max=1486120.00)
# ______________________________________________________________________________________
# ...

# %% [markdown]
# ### IMAGEN
# X = freesurfer feature-extracted h5files

# %%
show_h5_contents("/ritter/share/data/IMAGEN/h5files/newlbls-clean-*19a-binge*.h5", ignore='holdout')
# Out:
# ______________________________________________________________________________________
# filename: newlbls-clean-bl-espad-fu3-19a-binge-causal-onset1-n565.h5
#  h5.columns = ['Binge', 'X', 'i', 'sex', 'site']
#  h5.attrs = ['X_col_names', 'confs', 'labels']
# n = 565 	 label = Binge 	 X.shape = (565, 719)  	 confs = ['sex', 'site']
# label and conf with distributions:
# subject: 26722960 	 (min=0.00, mean=16018.98, max=1468921.00)
# ______________________________________________________________________________________
# filename: newlbls-clean-fu3-espad-fu3-19a-binge-n650.h5
#  h5.columns = ['Binge', 'X', 'i', 'sex', 'site']
#  h5.attrs = ['X_col_names', 'confs', 'labels']
# n = 650 	 label = Binge 	 X.shape = (650, 719)  	 confs = ['sex', 'site']
# label and conf with distributions:
# subject: 54766461 	 (min=0.00, mean=17625.06, max=1655840.00)
# ______________________________________________________________________________________
# ...

# %% [markdown]
# X = full brain voxels

# %%
#TODO # show_h5_contents("/ritter/share/data/IMAGEN/h5files/newlbls-clean-*19a-binge*.h5", ignore='')

# %% [markdown]
# ### NCANDA

# %% [markdown]
# X = freesurfer feature-extracted h5files

# %%
show_h5_contents("/ritter/share/data/NCANDA/h5files/*freesurfer*.h5", ignore='hold')
# Out:
# ______________________________________________________________________________________
# filename: freesurfer-features-all-demographics-drinking-occasions-imagen-occasion-n2599.h5
#  h5.columns = ['Occasion', 'X', 'i', 'sex']
#  h5.attrs = ['X_col_names', 'confs', 'labels']
# n = 2599 	 label = Occasion 	 X.shape = (2599, 923)  	 confs = ['sex']
# label and conf with distributions:
# subject: 121 	 (min=-1.93, mean=0.11, max=3.09)
# ______________________________________________________________________________________
# filename: freesurfer-features-fu2-demographics-liftime-binge-binge-n585.h5
#  h5.columns = ['Binge', 'X', 'i', 'sex']
#  h5.attrs = ['X_col_names', 'confs', 'labels']
# n = 585 	 label = Binge 	 X.shape = (585, 923)  	 confs = ['sex']
# label and conf with distributions:
# subject: 576 	 (min=-2.81, mean=-0.35, max=2.50)
# ______________________________________________________________________________________
# ...

# %% [markdown]
# X = brain images

# %%
show_h5_contents("/ritter/share/data/NCANDA/h5files/*mri-*.h5", ignore='hold')
# Out:
# ______________________________________________________________________________________
# filename: downsampled-mri-t1-bl-demographics-binge-drinking-fu1-y-n712.h5
#  h5.columns = ['X', 'age', 'i', 'sex', 'y']
#  h5.attrs = ['X_col_names', 'confs', 'labels']
# n = 712 	 label = y 	 X.shape = (712, 91, 109, 91)  	 confs = ['sex', 'age']
# label and conf with distributions:
# subject: 598 	 (min=-5.34, mean=20.03, max=218.56)
# Voxel value at [1,1,1]=0.0
# ______________________________________________________________________________________
# filename: mri-t1-fu3-demographics-drinking-occasions-imagen-frequency-n587.h5
#  h5.columns = ['Frequency', 'X', 'age', 'i', 'sex']
#  h5.attrs = ['X_col_names', 'confs', 'labels']
# n = 587 	 label = Frequency 	 X.shape = (587, 91, 109, 91)  	 confs = ['sex', 'age']
# label and conf with distributions:
# subject: 849 	 (min=-8.72, mean=20.96, max=179.63)
# Voxel value at [1,1,1]=-0.0
# ...

# %% [markdown]
# ### LEAD FOR1617
# X = full brain voxels

# %%
#TODO
